# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('../data/220808.xlsx')
data = data.fillna(method='ffill')
data.head()
# Out:
#                 Unnamed: 0 Unnamed: 1             Unnamed: 2  Total Accuracy  \
# 0  Logistic Regression_ISI     Data A  MultiOutputClassifier        0.686869
# 1  Logistic Regression_ISI     Data A  MultiOutputClassifier        0.683081
# 2  Logistic Regression_ISI     Data A        ClassifierChain        0.728535
# 3  Logistic Regression_ISI     Data A        ClassifierChain        0.702020
# 4  Logistic Regression_ISI     Data B  MultiOutputClassifier        0.704380
#
#    Accuracy_OSA  Accuracy_insomnia  Accuracy_PLMD,RLS  Accuracy_parasomnia  \
# 0      0.907828           0.922980           0.920455             0.957071
# 1      0.911616           0.921717           0.922980             0.955808
# 2      0.914141           0.916667           0.933081             0.958333
# 3      0.910354           0.926768           0.930556             0.958333
# 4      0.916058           0.912409           0.910584             0.955292
#
#    Accuracy_circadian  Accuracy_Narcolepsy,EDS,Hypersomnia  ...  F1_PLMD,RLS  \
# 0            0.979798                             0.979798  ...     0.571429
# 1            0.973485                             0.974747  ...     0.601307
# 2            0.978535                             0.979798  ...     0.644295
# 3            0.978535                             0.978535  ...     0.635762
# 4            0.985401                             0.979015  ...     0.443182
#
#    F1_parasomnia  F1_circadian  F1_Narcolepsy,EDS,Hypersomnia  F1_Catathrenia  \
# 0       0.150000      0.000000                       0.200000               0
# 1       0.339623      0.160000                       0.411765               0
# 2       0.326531      0.105263                       0.333333               0
# 3       0.326531      0.000000                       0.190476               0
# 4       0.289855      0.000000                       0.342857               0
#
#    F1_control  F1_micro  F1_macro  F1_weighted  F1_samples
# 0    0.551181  0.803198  0.355009     0.769113    0.757576
# 1    0.589928  0.802120  0.437367     0.792882    0.771044
# 2    0.633803  0.818991  0.436559     0.803056    0.795412
# 3    0.575758  0.813600  0.392552     0.788476    0.771212
# 4    0.675497  0.810329  0.392075     0.775801    0.774909
#
# [5 rows x 48 columns]

# %%
data.rename(columns={'Unnamed: 0':'ML_Algorithm', 'Unnamed: 1':'data_type', 'Unnamed: 2': 'method'}, inplace=True)
data.head()
# Out:
#               ML_Algorithm data_type                 method  Total Accuracy  \
# 0  Logistic Regression_ISI    Data A  MultiOutputClassifier        0.686869
# 1  Logistic Regression_ISI    Data A  MultiOutputClassifier        0.683081
# 2  Logistic Regression_ISI    Data A        ClassifierChain        0.728535
# 3  Logistic Regression_ISI    Data A        ClassifierChain        0.702020
# 4  Logistic Regression_ISI    Data B  MultiOutputClassifier        0.704380
#
#    Accuracy_OSA  Accuracy_insomnia  Accuracy_PLMD,RLS  Accuracy_parasomnia  \
# 0      0.907828           0.922980           0.920455             0.957071
# 1      0.911616           0.921717           0.922980             0.955808
# 2      0.914141           0.916667           0.933081             0.958333
# 3      0.910354           0.926768           0.930556             0.958333
# 4      0.916058           0.912409           0.910584             0.955292
#
#    Accuracy_circadian  Accuracy_Narcolepsy,EDS,Hypersomnia  ...  F1_PLMD,RLS  \
# 0            0.979798                             0.979798  ...     0.571429
# 1            0.973485                             0.974747  ...     0.601307
# 2            0.978535                             0.979798  ...     0.644295
# 3            0.978535                             0.978535  ...     0.635762
# 4            0.985401                             0.979015  ...     0.443182
#
#    F1_parasomnia  F1_circadian  F1_Narcolepsy,EDS,Hypersomnia  F1_Catathrenia  \
# 0       0.150000      0.000000                       0.200000               0
# 1       0.339623      0.160000                       0.411765               0
# 2       0.326531      0.105263                       0.333333               0
# 3       0.326531      0.000000                       0.190476               0
# 4       0.289855      0.000000                       0.342857               0
#
#    F1_control  F1_micro  F1_macro  F1_weighted  F1_samples
# 0    0.551181  0.803198  0.355009     0.769113    0.757576
# 1    0.589928  0.802120  0.437367     0.792882    0.771044
# 2    0.633803  0.818991  0.436559     0.803056    0.795412
# 3    0.575758  0.813600  0.392552     0.788476    0.771212
# 4    0.675497  0.810329  0.392075     0.775801    0.774909
#
# [5 rows x 48 columns]

# %%
df = data.pivot_table(index='ML_Algorithm', columns=['data_type', 'method'], values='Total Accuracy')
df
# Out:
# data_type                        Data A                                Data B  \
# method                  ClassifierChain MultiOutputClassifier ClassifierChain
# ML_Algorithm
# Logistic Regression_ESS        0.731692              0.720328        0.728271
# Logistic Regression_ISI        0.715278              0.684975        0.737682
# Logistic Regression_SSQ        0.782152              0.770341        0.789720
# Random Forest_ESS              0.751263              0.744949        0.711802
# Random Forest_ISI              0.706439              0.708965        0.704836
# Random Forest_SSQ              0.767717              0.751969        0.762850
# SVM_ESS                        0.651515              0.651515        0.649588
# SVM_ISI                        0.636364              0.636364        0.643248
# SVM_SSQ                        0.679790              0.679790        0.700935
#
# data_type
# method                  MultiOutputClassifier
# ML_Algorithm
# Logistic Regression_ESS              0.695334
# Logistic Regression_ISI              0.705292
# Logistic Regression_SSQ              0.762850
# Random Forest_ESS                    0.694876
# Random Forest_ISI                    0.697536
# Random Forest_SSQ                    0.745327
# SVM_ESS                              0.652333
# SVM_ISI                              0.648723
# SVM_SSQ                              0.700935

# %%
data_columns = data.columns[3:].tolist()
cols_list = [data_columns[i:i+6] for i in range(0, len(data_columns), 6)]

# %%
cols_list
# Out:
# [['Total Accuracy',
#   'Accuracy_OSA',
#   'Accuracy_insomnia',
#   'Accuracy_PLMD,RLS',
#   'Accuracy_parasomnia',
#   'Accuracy_circadian'],
#  ['Accuracy_Narcolepsy,EDS,Hypersomnia',
#   'Accuracy_Catathrenia',
#   'Accuracy_control',
#   'Precision_OSA',
#   'Precision_insomnia',
#   'Precision_PLMD,RLS'],
#  ['Precision_parasomnia',
#   'Precision_circadian',
#   'Precision_Narcolepsy,EDS,Hypersomnia',
#   'Precision_Catathrenia',
#   'Precision_control',
#   'Precision_micro'],
#  ['Precision_macro',
#   'Precision_weighted',
#   'Precision_samples',
#   'Recall_OSA',
#   'Recall_insomnia',
#   'Recall_PLMD,RLS'],
#  ['Recall_parasomnia',
#   'Recall_circadian',
#   'Recall_Narcolepsy,EDS,Hypersomnia',
#   'Recall_Catathrenia',
#   'Recall_control',
#   'Recall_micro'],
#  ['Recall_macro',
#   'Recall_weighted',
#   'Recall_samples',
#   'F1_OSA',
#   'F1_insomnia',
#   'F1_PLMD,RLS'],
#  ['F1_parasomnia',
#   'F1_circadian',
#   'F1_Narcolepsy,EDS,Hypersomnia',
#   'F1_Catathrenia',
#   'F1_control',
#   'F1_micro'],
#  ['F1_macro', 'F1_weighted', 'F1_samples']]

# %%
for cols in cols_list:
    plt.figure(figsize=(32, 18))
    plt.subplots_adjust(wspace=0.4, hspace=0.4)
    for i, col in enumerate(cols):
        df = data.pivot_table(index='ML_Algorithm', columns=['data_type', 'method'], values=col)
        ax = plt.subplot(2, 3, i+1)
        df.T.plot(kind='bar', ylabel=col, ax=ax)
        ax.legend(bbox_to_anchor=(1, 1))
        ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=45, ha='right')
